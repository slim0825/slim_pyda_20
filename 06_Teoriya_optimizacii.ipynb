# %%
import numpy as np
from scipy.optimize import differential_evolution
import matplotlib.pyplot as plt

# %%
def ackley(x):
    arg1 = -0.2 * np.sqrt(0.5 * (x[0] ** 2 + x[1] ** 2))
    arg2 = 0.5 * (np.cos(2. * np.pi * x[0]) + np.cos(2. * np.pi * x[1]))
    return -20. * np.exp(arg1) - np.exp(arg2) + 20. + np.e

bounds = [(-10, 10), (-10, 10)]

result = differential_evolution(ackley, bounds, seed=42)
result
# Out:
#      fun: 4.440892098500626e-16
#  message: 'Optimization terminated successfully.'
#     nfev: 2793
#      nit: 90
#  success: True
#        x: array([0., 0.])

# %% [markdown]
# При фиксированном seed=42 поразбирайтесь и поэкспериментируйте с параметрами алгоритма дифференциальной эволюции: strategy, popsize, tol, mutation, recombination и updating.
#
# Постройте графики количества итераций оптимизации функции ackley от значения параметра.

# %% [markdown]
# Дополнительное задание.
# Найти множество параметров (strategy=..., ..., updating=...), которые требуют минимального количества итераций.

# %%
### Strategy
strategy_ = ['best1bin', 'best1exp', 'rand1exp', 'randtobest1exp', 'currenttobest1exp', 'best2exp', 'rand2exp',
            'randtobest1bin', 'currenttobest1bin', 'best2bin', 'rand2bin', 'rand1bin']
def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, strategy = x)
    return result.get('nit')
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от strategy')
axes.set_xlabel('Strategy', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in strategy_], [f(x) for x in strategy_])

# %%
### Popsize
popsize_ = range(30)

def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, popsize = x)
    return result.get('nit')
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от Popsize')
axes.set_xlabel('Popsize', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in popsize_], [f(x) for x in popsize_])

# %%
### Tol
tol_ = np.arange(0, 1, 0.1)

def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, tol = x)
    return result.get('nit')
fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от Tol')
axes.set_xlabel('Tol', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in tol_], [f(x) for x in tol_])

# %%
### Mutation
mutation_ = np.arange(0, 2, 0.1)

def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, mutation = x)
    return result.get('nit')

fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от Mutation')
axes.set_xlabel('Mutation', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in mutation_], [f(x) for x in mutation_])

# %%
### Recombination
recombination_ = np.arange(0, 1, 0.1)

def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, recombination = x)
    return result.get('nit')

fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от Recombination_ ')
axes.set_xlabel('Recombination_ ', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in recombination_], [f(x) for x in recombination_])

# %%
### Updating
updating_ = range(10)

def f(x):                
    result = differential_evolution(ackley, bounds, seed=42, updating = x)
    return result.get('nit')

fig, axes = plt.subplots(figsize = (15, 6))
plt.title('График кол-ва итераций от Updating')
axes.set_xlabel('Updating ', fontsize = 12)
axes.set_ylabel('Кол-во итераций', fontsize = 12)
axes.tick_params(axis = 'x', labelsize = 8)
axes.plot([x for x in updating_], [f('immediate') for x in updating_], label = 'immediate')
axes.plot([x for x in updating_], [f('deferred') for x in updating_], label = 'deferred')
axes.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
