# %%
from IPython.display import Image
Image(filename='dz.png')

# %%
import numpy as np

# %%
trials = 100000    # Количество попыток
successes = 0    # Количество успехов
cash = 0
fails = 0

for i in range(trials):
    digit_ = str(np.random.randint(0, 1000)).zfill(3)
    if digit_ == 777:
        cash += 200
        successes += 1
    elif digit_ == 999:
        cash += 100
        successes += 1
    elif digit_ == 555:
        cash += 50
        successes += 1
    elif digit_ == 333:
        cash += 15
        successes += 1
    elif digit_ == 111:
        cash += 10
        successes += 1
    elif re.match(r'\d77', digit_):
        cash += 5
        successes += 1
    elif re.match(r'\d{2}7', digit_):
        cash += 3
        successes += 1
    elif re.match(r'\d00', digit_):
        cash += 2
        successes += 1
    elif re.match(r'\d{2}0', digit_):
        cash += 1
        successes += 1
    else:
        fails += 1
print(f'На {trials} попыток, вероятность выигрыша у лотерейного автомата: {successes / trials}')
print(f'Выигрыш: {cash} руб.')
print(f'Выигрыш от одной игры: {cash/trials} руб.')
print(f'Неудачных попыток: {fails}')
# Out:
# На 100000 попыток, вероятность выигрыша у лотерейного автомата: 0.20154
# Выигрыш: 43479 руб.
# Выигрыш от одной игры: 0.43479 руб.
# Неудачных попыток: 79846
